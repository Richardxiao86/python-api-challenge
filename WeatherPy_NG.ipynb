# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
import json

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 586

# %%
#cities=['Chicago','Detroit']
cities
# Out:
# ['bethel',
#  'happy valley-goose bay',
#  'tura',
#  'adamstown',
#  'daru',
#  'egilsstadir',
#  'thompson',
#  'puerto natales',
#  'kingston',
#  'bredasdorp',
#  'puerto ayora',
#  'blackmans bay',
#  'horta',
#  'port-aux-francais',
#  'gimbi',
#  'kodiak',
#  'margaret river',
#  'baardheere',
#  'road town',
#  'qaqortoq',
#  'badger',
#  'naze',
#  'henderson',
#  'waitangi',
#  'caleta olivia',
#  'haiku-pauwela',
#  'paveh',
#  'sinjai',
#  'grytviken',
#  'huarmey',
#  'edinburgh of the seven seas',
#  'kenai',
#  'ippy',
#  'kalkaman',
#  'eyl',
#  'stanley',
#  'argo',
#  'yatou',
#  'villa gesell',
#  'masterton',
#  'tarakan',
#  'salaverry',
#  'kirensk',
#  'fayetteville',
#  'muli',
#  'fort mcmurray',
#  'benoy',
#  'lucea',
#  'praia da vitoria',
#  'isafjordur',
#  'chibougamau',
#  'casilda',
#  'mount darwin',
#  'ta`u',
#  'fuvahmulah',
#  "mil'kovo",
#  'betong',
#  'whitehorse',
#  'tsiombe',
#  'gadzhiyevo',
#  'namibe',
#  'tolanaro',
#  'port alfred',
#  'luderitz',
#  'port mathurin',
#  'albany',
#  'cartagena',
#  'barinas',
#  'invercargill',
#  'west island',
#  'carnot',
#  'hawaiian paradise park',
#  'bilibino',
#  'iqaluit',
#  'trevelin',
#  'touros',
#  'holualoa',
#  'hermanus',
#  'fort bragg',
#  'goure',
#  "st. john's",
#  'flying fish cove',
#  'pizarro',
#  'abadeh',
#  'olonkinbyen',
#  'iquique',
#  'acarau',
#  'itaituba',
#  'ribeira grande',
#  'kingsville',
#  'qarazhal',
#  'yesilhisar',
#  'mount pearl',
#  'palikir - national government center',
#  'ilulissat',
#  'ebon',
#  'al artawiyah',
#  'coyhaique',
#  'siwa oasis',
#  'papao',
#  'college',
#  'tazovsky',
#  'manismata',
#  'constantia',
#  'taroa',
#  'mili',
#  'salalah',
#  'floro',
#  'farkhor',
#  "'ohonua",
#  'novodvinsk',
#  'inarajan village',
#  'uyuni',
#  'corinto',
#  'havre',
#  'mejit',
#  'lebu',
#  'ar raqqah',
#  'afaahiti',
#  'arucas',
#  'petropavlovsk-kamchatsky',
#  'walvis bay',
#  'wailua homesteads',
#  'itamaraca',
#  'kapuskasing',
#  "nar'yan-mar",
#  'pilar',
#  'tamarin',
#  'jamestown',
#  'tambura',
#  'mareeba',
#  'ghat',
#  "mohale's hoek",
#  'nemuro',
#  'florence',
#  'newport',
#  'antsiranana',
#  'georgetown',
#  'barra',
#  'itarantim',
#  'sao tome',
#  'sitka',
#  'taiohae',
#  'malango',
#  'chaman',
#  'kuta',
#  "ma'an",
#  'ashland',
#  'rupert',
#  'fonadhoo',
#  'el alto',
#  'tralee',
#  'udachny',
#  'labytnangi',
#  'saipan',
#  'faaa',
#  'klyuchi',
#  'inonu',
#  'ushuaia',
#  'east london',
#  'ben gardane',
#  'yellowknife',
#  'howard springs',
#  'ola',
#  'al mijlad',
#  'alofi',
#  'hamilton',
#  'san luis de la loma',
#  'enzan',
#  'howrah',
#  'malabar',
#  'rabaul',
#  'ouellah',
#  "kapa'a",
#  'trincomalee',
#  'longyearbyen',
#  'azemmour',
#  'guerrero negro',
#  'trikala',
#  'namtsy',
#  'santyoku',
#  'borkum',
#  'vingt cinq',
#  'labrador city',
#  'kruisfontein',
#  'zaozersk',
#  'chebba',
#  'ourilandia do norte',
#  'anloga',
#  'quellon',
#  'karachayevsk',
#  'cookeville',
#  'tidjikja',
#  'plastun',
#  'prado',
#  'soio',
#  'puerto san jose',
#  'minas de marcona',
#  'nema',
#  'vilyuchinsk',
#  'salekhard',
#  'prince rupert',
#  'al kharj',
#  'port elizabeth',
#  'codrington',
#  'utrik',
#  'papatowai',
#  'chonchi',
#  'carnarvon',
#  'zalingei',
#  'laguna',
#  'marudi',
#  'fisterra',
#  'aral',
#  'vila do maio',
#  'mogocha',
#  'tsagan aman',
#  'talnakh',
#  'souillac',
#  'nanao',
#  'turpan',
#  'sinan',
#  "nuku'alofa",
#  'parasia',
#  'lamar',
#  'grand falls-windsor',
#  'coquimbo',
#  'zaragoza',
#  'smara',
#  'wangqing',
#  'farsan',
#  'itamarandiba',
#  'alesund',
#  'carora',
#  'cidade velha',
#  'weno',
#  'guigang',
#  'roma',
#  'puerto san carlos',
#  'uturoa',
#  'enewetak',
#  'dunedin',
#  'yung shue wan',
#  'hithadhoo',
#  'marconia',
#  'swan hill',
#  'saint-pierre',
#  'kingscliff',
#  'san patricio',
#  'codajas',
#  'dawei',
#  'punta arenas',
#  'graaff-reinet',
#  'oranjemund',
#  'anadyr',
#  'cockburn town',
#  'kittila',
#  'rice lake',
#  'bubaque',
#  'kayangel',
#  'iskateley',
#  'bonthe',
#  'tamanrasset',
#  'huanan',
#  'hammerfest',
#  'yarmouth',
#  'sao jose de ribamar',
#  'tazacorte',
#  'vadso',
#  'pontianak',
#  'louis trichardt',
#  'kertih',
#  'kodinsk',
#  'leshan',
#  'la ronge',
#  'suva',
#  'myeik',
#  'parauna',
#  'ust-nera',
#  'margate',
#  'papayal',
#  'isangel',
#  'tikrit',
#  'cruzeiro do sul',
#  'villazon',
#  'kismayo',
#  'ratnagiri',
#  'natal',
#  'huamachuco',
#  'buala',
#  'rio san juan',
#  'novyy urengoy',
#  'puerto lempira',
#  'san antonio de pale',
#  'lihue',
#  'sterling',
#  'raduzhny',
#  'segou',
#  'ilhabela',
#  'sunne',
#  'magadan',
#  'geraldton',
#  'ironwood',
#  'khandyga',
#  'durazno',
#  'luganville',
#  'pangoa',
#  'kudahuvadhoo',
#  'ilaro',
#  'lata',
#  'lerwick',
#  'kerikeri',
#  'aldinga beach',
#  'nungua',
#  'port macquarie',
#  'reggane',
#  'merida',
#  'saldanha',
#  'bam',
#  'rio gallegos',
#  'port blair',
#  'pangody',
#  'turkmenbasy',
#  'tocopilla',
#  'hlukhiv',
#  'susuman',
#  'el hadjira',
#  'new norfolk',
#  'sawa sawa',
#  'richards bay',
#  'fale old settlement',
#  'atafu village',
#  'tiksi',
#  'zeya',
#  'albertina',
#  'tofol',
#  'northam',
#  'jiangyou',
#  'krasnyy chikoy',
#  'bamboo flat',
#  'imbituba',
#  'astrakhan',
#  'kijang',
#  'pyay',
#  'general acha',
#  'nova sintra',
#  'levuka',
#  'christchurch',
#  'cargados carajos',
#  'nantucket',
#  'lompoc',
#  'osorno',
#  'bykovo',
#  'castillos',
#  'maun',
#  'newman',
#  'brisas de zicatela',
#  'yelizovo',
#  'steinbach',
#  'kouroussa',
#  'ishinomaki',
#  'pont rouge',
#  'sydney',
#  'katsuura',
#  'preobrazheniye',
#  'paka',
#  'vorontsovka',
#  'mata-utu',
#  'ribeira brava',
#  'cooma',
#  'chernolesskoye',
#  'tabou',
#  'jayapura',
#  'timon',
#  'inhambane',
#  'nacala',
#  'prabumulih',
#  'ban su-ngai pa di',
#  'nanning',
#  'prince george',
#  'banda aceh',
#  'sola',
#  'lionel town',
#  'divnogorsk',
#  'poronaysk',
#  'myshkin',
#  'kursenai',
#  'vorgashor',
#  'nadi',
#  'juneau',
#  'tabas',
#  'bomdila',
#  'chernyshevskiy',
#  'rumoi',
#  'pemba',
#  'isle of lewis',
#  'dornach',
#  'sakakah',
#  'pathein',
#  'keflavik',
#  'santa marta',
#  'palangkaraya',
#  'general pico',
#  'piti village',
#  'rio grande',
#  'beroroha',
#  'avesta',
#  'celestun',
#  'galion',
#  'hadibu',
#  'ujae',
#  'cannonvale',
#  'caala',
#  'am djarass',
#  'paita',
#  'lashio',
#  'ancud',
#  'arraial do cabo',
#  'humaita',
#  'majuro',
#  'mount gambier',
#  'durant',
#  'al bawiti',
#  'medicine hat',
#  'kande',
#  'alta',
#  'aasiaat',
#  'rongelap',
#  'cabo san lucas',
#  'kutum',
#  'timbauba',
#  'brokopondo',
#  'beya',
#  'waddan',
#  'llanes',
#  'pocone',
#  'sarkand',
#  'pemangkat',
#  'leer',
#  'yangor',
#  'mtambile',
#  'abepura',
#  'aripuana',
#  'shihezi',
#  'shalqar',
#  'menongue',
#  'paradip garh',
#  'lahad datu',
#  'mana',
#  'cestos city',
#  'yaren',
#  'carauari',
#  'ulverstone',
#  'barreiras',
#  'pantai remis',
#  "kem'",
#  'aykhal',
#  'kailua-kona',
#  'ushibukamachi',
#  'vuktyl',
#  'dock junction',
#  'chernomorskoye',
#  'talakan',
#  'greymouth',
#  'rukban',
#  'isla mujeres',
#  'avarua',
#  'canavieiras',
#  'tsumeb',
#  'al jaradiyah',
#  'gambela',
#  'nadym',
#  'qianzhou',
#  'teknaf',
#  'port douglas',
#  'dudinka',
#  'tadine',
#  'halifax',
#  "mek'ele",
#  'kimbe',
#  'sohbatpur',
#  'coahuayana de hidalgo',
#  'alice springs',
#  'lakatoro',
#  'posto fiscal rolim de moura',
#  'cambria',
#  'kidal',
#  'portland',
#  'las heras',
#  "dzhalil'",
#  'pacific grove',
#  'solleftea',
#  'mikhaylovskoye',
#  'kristiansund',
#  'scarborough',
#  'jalgaon jamod',
#  'novo aripuana',
#  'zhangjiakou',
#  'srivardhan',
#  'shaowu',
#  'kisangani',
#  'al ghayzah',
#  'patur',
#  'luanda',
#  'knyaze-volkonskoye',
#  'fortuna',
#  'mwanza',
#  'pisco',
#  'coihueco',
#  'guadalupe y calvo',
#  'zhanaozen',
#  'amreli',
#  'bodo',
#  'kulia village',
#  'thinadhoo',
#  'salmon arm',
#  'puerto colombia',
#  'at-bashi',
#  'ciudad lazaro cardenas',
#  'bikenibeu village',
#  'worthington',
#  'homer',
#  'harper',
#  'volterra',
#  'igrim',
#  'yuzhno-kurilsk',
#  'djamaa',
#  'falmouth',
#  'hindupur',
#  'taroudant',
#  'griffith',
#  'vanimo',
#  'zhangatas',
#  'ocean city',
#  'gemena',
#  'kone',
#  'mabamba',
#  'island harbour',
#  'sao joao da barra',
#  'al jubayl',
#  'illapel',
#  'grand gaube',
#  'thunder bay',
#  'altamont',
#  'byford',
#  'ahar',
#  'el parral',
#  "hayma'",
#  'palmer',
#  'kayyerkan',
#  'north side',
#  'kissidougou',
#  'kalmunai',
#  'bechar',
#  'fort saskatchewan',
#  'ballina',
#  'saratamata',
#  'mount isa',
#  'grand-lahou',
#  'port isabel',
#  'qina',
#  'vila velha',
#  'hola',
#  'charters towers',
#  'bryan',
#  'santa catarina mita',
#  'paramonga',
#  "la'ie",
#  'semenivka',
#  'labuan lombok',
#  'tanjung selor',
#  'rusape',
#  'aparecida do taboado',
#  'kabansk',
#  'cascais',
#  'jieshi',
#  "severobaykal'sk",
#  'takaungu',
#  'fraserburgh',
#  'beitbridge',
#  'bodden town',
#  "dul'durga",
#  'sodra sandby',
#  'fuglafjordur',
#  'lodwar',
#  'altai']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'https://api.openweathermap.org/data/2.5/weather?'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=metric&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date
                         })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | happy valley-goose bay
# Processing Record 3 of Set 1 | tura
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | daru
# Processing Record 6 of Set 1 | egilsstadir
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | puerto natales
# Processing Record 9 of Set 1 | kingston
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | blackmans bay
# Processing Record 13 of Set 1 | horta
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | gimbi
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | margaret river
# Processing Record 18 of Set 1 | baardheere
# Processing Record 19 of Set 1 | road town
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | badger
# Processing Record 22 of Set 1 | naze
# Processing Record 23 of Set 1 | henderson
# Processing Record 24 of Set 1 | waitangi
# Processing Record 25 of Set 1 | caleta olivia
# Processing Record 26 of Set 1 | haiku-pauwela
# Processing Record 27 of Set 1 | paveh
# Processing Record 28 of Set 1 | sinjai
# Processing Record 29 of Set 1 | grytviken
# Processing Record 30 of Set 1 | huarmey
# Processing Record 31 of Set 1 | edinburgh of the seven seas
# Processing Record 32 of Set 1 | kenai
# Processing Record 33 of Set 1 | ippy
# Processing Record 34 of Set 1 | kalkaman
# Processing Record 35 of Set 1 | eyl
# Processing Record 36 of Set 1 | stanley
# Processing Record 37 of Set 1 | argo
# Processing Record 38 of Set 1 | yatou
# Processing Record 39 of Set 1 | villa gesell
# Processing Record 40 of Set 1 | masterton
# Processing Record 41 of Set 1 | tarakan
# Processing Record 43 of Set 4 | plastun
# Processing Record 44 of Set 4 | prado
# Processing Record 45 of Set 4 | soio
# Processing Record 46 of Set 4 | puerto san jose
# Processing Record 47 of Set 4 | minas de marcona
# Processing Record 48 of Set 4 | nema
# Processing Record 49 of Set 4 | vilyuchinsk
# Processing Record 0 of Set 5 | salekhard
# Processing Record 1 of Set 5 | prince rupert
# Processing Record 2 of Set 5 | al kharj
# Processing Record 3 of Set 5 | port elizabeth
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | utrik
# Processing Record 6 of Set 5 | papatowai
# Processing Record 7 of Set 5 | chonchi
# Processing Record 8 of Set 5 | carnarvon
# Processing Record 9 of Set 5 | zalingei
# Processing Record 10 of Set 5 | laguna
# Processing Record 11 of Set 5 | marudi
# City not found. Skipping...
# Processing Record 12 of Set 5 | fisterra
# Processing Record 13 of Set 5 | aral
# Processing Record 14 of Set 5 | vila do maio
# Processing Record 15 of Set 5 | mogocha
# Processing Record 16 of Set 5 | tsagan aman
# Processing Record 17 of Set 5 | talnakh
# Processing Record 18 of Set 5 | souillac
# Processing Record 19 of Set 5 | nanao
# Processing Record 20 of Set 5 | turpan
# Processing Record 21 of Set 5 | sinan
# Processing Record 22 of Set 5 | nuku'alofa
# Processing Record 23 of Set 5 | parasia
# Processing Record 24 of Set 5 | lamar
# Processing Record 25 of Set 5 | grand falls-windsor
# Processing Record 26 of Set 5 | coquimbo
# Processing Record 27 of Set 5 | zaragoza
# Processing Record 28 of Set 5 | smara
# Processing Record 29 of Set 5 | wangqing
# Processing Record 30 of Set 5 | farsan
# Processing Record 31 of Set 5 | itamarandiba
# Processing Record 32 of Set 5 | alesund
# Processing Record 33 of Set 5 | carora
# Processing Record 34 of Set 5 | cidade velha
# Processing Record 35 of Set 5 | weno
# Processing Record 36 of Set 5 | guigang
# Processing Record 37 of Set 5 | roma
# Processing Record 38 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 39 of Set 5 | uturoa
# Processing Record 40 of Set 5 | enewetak
# Processing Record 41 of Set 5 | dunedin
# Processing Record 42 of Set 5 | yung shue wan
# Processing Record 43 of Set 5 | hithadhoo
# Processing Record 44 of Set 5 | marconia
# Processing Record 45 of Set 5 | swan hill
# Processing Record 46 of Set 5 | saint-pierre
# Processing Record 47 of Set 5 | kingscliff
# Processing Record 48 of Set 5 | san patricio
# Processing Record 49 of Set 5 | codajas
# Processing Record 0 of Set 6 | dawei
# Processing Record 1 of Set 6 | punta arenas
# Processing Record 2 of Set 6 | graaff-reinet
# Processing Record 3 of Set 6 | oranjemund
# Processing Record 4 of Set 6 | anadyr
# Processing Record 5 of Set 6 | cockburn town
# Processing Record 6 of Set 6 | kittila
# Processing Record 7 of Set 6 | rice lake
# Processing Record 8 of Set 6 | bubaque
# Processing Record 9 of Set 6 | kayangel
# Processing Record 10 of Set 6 | iskateley
# Processing Record 11 of Set 6 | bonthe
# Processing Record 12 of Set 6 | tamanrasset
# Processing Record 13 of Set 6 | huanan
# Processing Record 14 of Set 6 | hammerfest
# Processing Record 15 of Set 6 | yarmouth
# Processing Record 16 of Set 6 | sao jose de ribamar
# Processing Record 17 of Set 6 | tazacorte
# Processing Record 12 of Set 12 | hola
# Processing Record 13 of Set 12 | charters towers
# Processing Record 14 of Set 12 | bryan
# Processing Record 15 of Set 12 | santa catarina mita
# Processing Record 16 of Set 12 | paramonga
# Processing Record 17 of Set 12 | la'ie
# Processing Record 18 of Set 12 | semenivka
# Processing Record 19 of Set 12 | labuan lombok
# City not found. Skipping...
# Processing Record 20 of Set 12 | tanjung selor
# Processing Record 21 of Set 12 | rusape
# Processing Record 22 of Set 12 | aparecida do taboado
# Processing Record 23 of Set 12 | kabansk
# Processing Record 24 of Set 12 | cascais
# Processing Record 25 of Set 12 | jieshi
# Processing Record 26 of Set 12 | severobaykal'sk
# Processing Record 27 of Set 12 | takaungu
# Processing Record 28 of Set 12 | fraserburgh
# Processing Record 29 of Set 12 | beitbridge
# Processing Record 30 of Set 12 | bodden town
# Processing Record 31 of Set 12 | dul'durga
# Processing Record 32 of Set 12 | sodra sandby
# Processing Record 33 of Set 12 | fuglafjordur
# Processing Record 34 of Set 12 | lodwar
# Processing Record 35 of Set 12 | altai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          568
# Lat           568
# Lng           568
# Max Temp      568
# Humidity      568
# Cloudiness    568
# Wind Speed    568
# Country       568
# Date          568
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                  bethel  41.3712  -73.4140     28.44        80          97
# 1  happy valley-goose bay  53.3168  -60.3315     18.17       100         100
# 2                    tura  25.5198   90.2201     24.29        99         100
# 3               adamstown -25.0660 -130.1015     20.09        58          99
# 4                    daru  -9.0763  143.2092     25.63        82          80
#
#    Wind Speed Country        Date
# 0        0.89      US  1720569655
# 1        1.54      CA  1720569955
# 2        3.05      IN  1720569783
# 3        4.65      PN  1720569956
# 4        7.16      PG  1720569957

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../final/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../final/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                        bethel  41.3712  -73.4140     28.44        80
# 1        happy valley-goose bay  53.3168  -60.3315     18.17       100
# 2                          tura  25.5198   90.2201     24.29        99
# 3                     adamstown -25.0660 -130.1015     20.09        58
# 4                          daru  -9.0763  143.2092     25.63        82
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                97        0.89      US  1720569655
# 1               100        1.54      CA  1720569955
# 2               100        3.05      IN  1720569783
# 3                99        4.65      PN  1720569956
# 4                80        7.16      PG  1720569957

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title('City Latitude vs.Temperature(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("../final/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs.Humidity(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("../final/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs.Cloudiness(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("../final/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title('City Latitude vs.Wind Speed(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("../final/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg(x_axis, y_axis,eq_loc):  
    correlation = st.pearsonr(x_axis,y_axis)
    p_slope, p_int, p_r, p_p, p_std_err = st.linregress(x_axis, y_axis)
    p_fit = p_slope * x_axis + p_int
    eq= f"y ={p_slope: .2f}x +{ p_int: .2f}"
       
    #Plot the line
    plt.scatter(x_axis, y_axis ,marker="o")
    plt.plot(x_axis,p_fit,"--", color='red')
    plt.annotate(eq, eq_loc, fontsize=12, color='red')
    print(f"The r-value between {x_axis.name} and {y_axis.name} is {round(correlation[0],2)}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                        bethel  41.3712 -73.4140     28.44        80
# 1        happy valley-goose bay  53.3168 -60.3315     18.17       100
# 2                          tura  25.5198  90.2201     24.29        99
# 5                   egilsstadir  65.2653 -14.3948     12.95        71
# 6                      thompson  55.7435 -97.8558     24.09        43
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                97        0.89      US  1720569655
# 1               100        1.54      CA  1720569955
# 2               100        3.05      IN  1720569783
# 5                 0        4.63      IS  1720569851
# 6                40        2.06      CA  1720569765

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3             adamstown -25.0660 -130.1015     20.09        58          99
# 4                  daru  -9.0763  143.2092     25.63        82          80
# 7        puerto natales -51.7236  -72.4875      5.08        83          98
# 9            bredasdorp -34.5322   20.0403     11.19        79          87
# 10         puerto ayora  -0.7393  -90.3518     20.86       100          80
#
#          Wind Speed Country        Date
# City_ID
# 3              4.65      PN  1720569956
# 4              7.16      PG  1720569957
# 7              6.79      CL  1720569694
# 9              9.42      ZA  1720569961
# 10             2.76      EC  1720569961

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],(10, -10))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')
# Out:
# The r-value between Lat and Max Temp is -0.58
# Text(0, 0.5, 'Temperature(C)')

# %%
# Linear regression on Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],(-30, 5))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')
# Out:
# The r-value between Lat and Max Temp is 0.79
# Text(0, 0.5, 'Temperature(C)')

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere, a city's latitude and temperature have a strong negative coorelation(-0.81) - that is to say the higher latitude of the city, the lower temperature the city would be. On the contrary, in southern hemisphere, a city's latitude and temperature have a fair positive coorelation(0.73) - that is to say the higher latitude of the city, the higher temperature the city would be.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'],(55, 10))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
# Out:
# The r-value between Lat and Humidity is 0.16
# Text(0, 0.5, 'Humidity(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'],(-50, 25))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
# Out:
# The r-value between Lat and Humidity is -0.04
# Text(0, 0.5, 'Humidity(%)')

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere, a city's latitude and humidity have a weak positive coorelation(0.16) - that is to say with latitude increase, city's humidity is likely to increase but not much, in southern hemisphere, a city's latitude and humidity also have a weak positive coorelation(0.08) - that is to say with latitude increase, city's humidity is likely to increase but quick minimal.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'],(50, 50))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
# Out:
# The r-value between Lat and Cloudiness is -0.09
# Text(0, 0.5, 'Cloudiness(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'],(-50, 65))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
# Out:
# The r-value between Lat and Cloudiness is -0.06
# Text(0, 0.5, 'Cloudiness(%)')

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere, a city's latitude and cloudiness level have almost no coorelation(0.02) - that is to say a city's cloudiness level does not much related to its latitude, in southern hemisphere, it is a similar situation with almost no coorelation(0.17) between city's latitude and cloudiness level.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'],(10, 12))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
# Out:
# The r-value between Lat and Wind Speed is -0.12
# Text(0, 0.5, 'Wind Speed(m/s)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'],(-50, 9))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
# Out:
# The r-value between Lat and Wind Speed is -0.19
# Text(0, 0.5, 'Wind Speed(m/s)')

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere, a city's latitude and wind speed have no coorelation(0.00) - that is to say a city's windy level does not much related to its latitude, in southern hemisphere, it is a similar situation with very minor negative coorelation(-0.17) between city's latitude and wind speed.
